# %%
#Operadores de comparacion <,>,=,==,=!,>=,<=

mi_bool = 10==25 #Es igual a 25?
print(mi_bool)

mi_bool = 5+5==18-8 #Son iguales?
print(mi_bool)

mi_bool = 'blanco'=='Blanco'.lower()
print(mi_bool)

mi_bool = '100'==100
print(mi_bool)

mi_bool = 100.0==100
print(mi_bool)

mi_bool = 100 != 100
print(mi_bool)

mi_bool = 100 != 99
print(mi_bool)

mi_bool = 100 < 300
print(mi_bool)

mi_bool = 100 > 300
print(mi_bool)


#Ejercicios
#1.
num1 = 36
num2 = 17
mi_bool = num1>=num2
print(mi_bool)

#2.
num1 = 25**0.50
num2 = 5
mi_bool = num1 == num2
print(mi_bool)

#3.
num1 = 64*3
num2 = 24*8
mi_bool = num1 != num2
print(mi_bool)
# Out:
# False
# True
# True
# False
# True
# False
# True
# True
# False
# True
# True
# False

# %%
#Operadores logicos
#or, and o not

mi_bool = 4 < 5 < 6
print(mi_bool)

mi_bool = 4 < 5 and 5 > 6 #Para que de verdadero tienen que ser las 2 verdaderas
print(mi_bool)

mi_bool = 4 < 5 or 5 > 6 #Alguna de las 2 se cumple
print(mi_bool)

mi_bool = (55 == 55) and ('perro' == 'perro')
print(mi_bool)

mi_bool = 10 == 10 or 3 == 3 
print(mi_bool)

mi_bool = 10 == 1 or 3 == 3 # si se cumple alguna va a dar true
print(mi_bool)



texto = "esta frase es breve"
mi_bool = 'frase' in texto
print(mi_bool)

texto = "esta frase es breve"
mi_bool = ('frase' in texto) and ('breve' in texto)
print(mi_bool)


mi_bool = not ('a' == 'a') #
print(mi_bool)

mi_bool = not ('a' != 'a') # a no es diferente a a
print(mi_bool)


#Ejercicios
#1.
num1 = 36
num2 = 72/2
num3 = 48

mi_bool = num1 > num2 < num3
print(mi_bool)

#2.
num1 = 36
num2 = 72/2
num3 = 48

mi_bool = num1 > num2 or num2 < num3
print(mi_bool)

#3.
frase = "Cuando algo es lo suficientemente importante, lo haces incluso si las probabilidades de que salga bien no te acompañan"
palabra1 = "éxito"
palabra2 = "tecnología"

mi_bool = not palabra1 in frase and not palabra2 in frase
print(mi_bool)
# Out:
# True
# False
# True
# True
# True
# True
# True
# True
# False
# True
# False
# True
# True

# %%
#Control de flujo
#IF, ELIF, ELSE
#Sintaxis = if una_condicion:
#               print(codigo_a)
#           elif:
#               print(codigo_c)
#           elif:
#               print(codigo_d)
#           else:
#               print(codigo_b)


if 10 > 9:
    print("Es correcto")

if True:
        print("Es correcto")

x= True
if x:
      print("es correcto")

if 5 == 2:
    print("Es correcto")
else:
      print("no es correcto")


mascota = "perro"

if mascota == 'gato':
      print("Tienes un gato")
elif mascota == 'perro':
      print("Tienes un perro")
elif mascota == 'pez':
      print("Tienes un pez")
else:
      print("no se que animal tienes")




edad = 16
calificacion = 9

if edad < 18:
    print("Eres menor de edad")
    if calificacion >= 7:
        print('aprobado')
    else:
      print("Reprobado")
else:
      print("Eres adulto")



#Ejercicio

#1.
num1 = int(input("Ingresa un número:"))
num2 = int(input("Ingresa otro número:"))

if num1 > num2:
    print(f"{num1} es mayor que {num2}")
elif num2 > num1:
    print(f"{num2} es mayor que {num1}")
elif num1 == num2:
    print(f"{num1} y {num2} son iguales")
else:
    print("Jej")


#2.
edad = 16
tiene_licencia = False

if edad >= 18:
    print("Puedes conducir")
elif edad < 18:
    print("No puedes conducir aún. Debes tener 18 años y contar con una licencia")
elif tiene_licencia is False:
    print("No puedes conducir. Necesitas contar con una licencia")
else:
    print("Tienes licencia. Puedes conducir")
    

#3.
habla_ingles = True
sabe_python = False

if habla_ingles is True and sabe_python is True:
    print("Cumples con los requisitos para postularte")
elif habla_ingles is False and sabe_python is True:
    print("Para postularte, necesitas saber programar en Python y tener conocimientos de inglés")
elif habla_ingles is False and sabe_python  is True:
    print("Para postularte, necesitas tener conocimientos de inglés")
else:
    print("Para postularte, necesitas saber programar en Python")
# Out:
# Es correcto
# Es correcto
# es correcto
# no es correcto
# Tienes un perro
# Eres menor de edad
# aprobado
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[275], line 60
#      53       print("Eres adulto")
#      57 #Ejercicio
#      58
#      59 #1.
# ---> 60 num1 = int(input("Ingresa un número:"))
#      61 num2 = int(input("Ingresa otro número:"))
#      63 if num1 > num2:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#Loops
#Se diferencian en las definidas y las indefinidas

#Loop For

lista = ['a','b','c']

for letra in lista:
    print(letra)

lista = ['a','b','c','d']

for letra in lista:
    numero_letra = lista.index(letra) + 1
    print(f"Letra {numero_letra}: {letra}")


lista = ['pablo', 'laura', 'fede','luis','julia']

for nombre in lista:
    if nombre.startswith('l'):
        print(nombre)
    else:
        print(f"{nombre} que no comienza con 'l'")


numeros = [1,2,3,4,5]
mi_valor = 0

for numero in numeros:
    mi_valor = mi_valor + numero #mi valor vale 0, pero al hacer q esa variable sea igual a "LA VARIABLE + NUMERO
    #que numero en numeros es el que recorre la lista
print(mi_valor)

palabra = 'python'

for letra in palabra:
    print(letra)


for letra in "python":
    print(letra)




for a,b in [[1,2], [3,4],[5,6]]:
    print(a)
    print(b)


dic = {'clave':'a', 'clave':'b', 'clave3':'c'}

for item in dic.items():
    print(item)

for item in dic.values():
    print(item)

for a,b in dic.items():
    print(a,b)

# %%
#Ejercicios

#1.
alumnos_clase = ["María", "José", "Carlos", "Martina", "Isabel", "Tomás", "Daniela"]

for nombre in alumnos_clase:
    print(f"Hola {nombre}")

#2.
lista_numeros = [1,5,8,7,6,8,2,5,2,6,4,8,5,9,8,3,5,4,2,5,6,4]
suma_numeros = 0
for numero in lista_numeros:
    suma_numeros = suma_numeros + numero
print(suma_numeros)

#3.
lista_numeros = [1,5,8,7,6,8,2,5,2,6,4,8,5,9,8,3,5,4,2,5,6,4]
suma_pares = 0
suma_impares = 0
for numero in lista_numeros:
    if numero %2==0:
        suma_pares += numero
    else:
        suma_impares += numero
print("Suma de numeros pares", suma_pares)
print("Suma de numeros impares", suma_impares)

# %%
#Loop While

#Se repiten mientras se cumple una condicion.

#while una_condicion:
    #este_codigo
#else
    #otro_codigo

monedas = 5

while monedas > 0:
    print(f"tengo {monedas} monedas")
    monedas -= 1
else:
    print(f"no tengo mas monedas")



respuesta = 's'
while respuesta == 's':
    respuesta = input("¿Quieres seguir? (s/n)")
else:
    print("Gracias")

# %%
nombre = input("Tu nombre: ")
for letra in nombre:
    if letra == 'r':
        break
    print(letra)



nombre = input("Tu nombre: ")
for letra in nombre:
    if letra == 'r':
        continue
    print(letra)

# %%
#ejercicios

#1.
numero = 10
while numero > -1:
    print(numero)
    numero -= 1
#2.
numero = 50
while numero >= 0:
    if numero % 5 == 0:
        print(numero)
    numero -= 1

#3.

lista_numeros = [4, 5, 8, 7, 6, 9, 8, 2, 4, 5, 7, 1, 9, 5, 6, -1, -5, 6, -6, -4, -3]

for numero in lista_numeros:
    if numero < 0:
        break  # Interrumpe el loop si el número es negativo
    print(numero)

# %%
#Range
#Es una funcion que facilita las iteraciones


#forma de lista
lista = [1,2,3,4,5]
for numero in lista:
    print(numero)

#forma con #range

for numero in range(5):
    print(numero)

#forma de decirle desde donde empieza   
for numero in range(1,5):
    print(numero)

#forma de decirle cuantos pasos haga, o sea de 2 en 2 en este caso
for numero in range(1,5,2):
    print(numero)


#usar fuera de los loops
#lista del 0 al 100

lista = list(range(1,101)) #101 porq el indice empieza desde 0

# %%
#Ejercicios:

#1.
mi_lista = list(range(2500,2586))
#2.
mi_lista = list(range(3,301,3))
#3.
suma_cuadrados = 0

for numero in list(range(1,16)):
    cuadrado = numero**2
    suma_cuadrados += cuadrado
print(suma_cuadrados)

# %%
#Funcion enumerate

lista = ['a','b','c']

for item in enumerate(lista):
    print(item)

    
for indice,item in enumerate(range(50,55)):
    print(indice,item)

lista = ['a','b','c']

mis_tuples = list(enumerate(lista))
print(mis_tuples[1])

# %%
#Ejercicios

#1.

lista_nombres = ["Marcos", "Laura", "Mónica", "Javier", "Celina", "Marta", "Darío", "Emiliano", "Melisa"]
for indice,nombre in enumerate(lista_nombres):
    print(f'{nombre} se encuentra en el índice {indice}')

#2.
lista_indices = list(enumerate("Python"))
print(lista_indices)

#3.
lista_nombres = ["Marcos", "Laura", "Mónica", "Javier", "Celina", "Marta", "Darío", "Emiliano", "Melisa"]

for indice,nombre in enumerate(lista_nombres):
    if nombre.startswith("M"):
        print(indice)

# %%
#Funcion ZIP

nombres = ["Ana","Hugo","Valeria"]
edades = [65,29,42]
ciudades = ["Lima","Madrid","Mexico"]

#para juntar las 2 listas con zip

combinados = list(zip(nombres,edades,ciudades))
print(combinados)

for nombre,edad,ciudades in combinados:
    print(f"{nombre} tiene {edad} años y vive en {ciudades}")

# %%
#Ejercicios

#1.
capitales = ["Berlín", "Tokio", "París", "Helsinki", "Ottawa", "Canberra"]
paises = ["Alemania", "Japón", "Francia", "Finlandia", "Canadá", "Australia"]

combinados = list(zip(capitales,paises))

for capitales,paises in combinados:
    print(f"La capital de {paises} es {capitales}")

#2.
marcas = ["Malboro","Decathlon","Dell"]
productos = ["Cigarrillos", "Ropa Deportiva","Portatiles y Ordenadores"]

mi_zip = zip(marcas,productos)
print(list(mi_zip))

#3.

num1 = ["uno","dos","tres","cuatro","cinco"]
num2 = ["um","dois","três","quatro","cinco"]
num3 = ["one","two","three","four","five"]

numeros = list(zip(num1,num2,num3))
print(numeros)

# %%
#Min y Max

menor =  min(58,96,72,63,35)
print(menor)

mayor =  max(58,96,72,63,35)
print(mayor)


lista = [58,96,72,63,35]
print(f"El menor es {min(lista)} y el mayor es {max(lista)}")


nombre = ['Juan','Pablo', 'Alicia', 'Carlos']
print(min(nombre))

nombre = "Carlos"
print(min(nombre.lower()))

dic = {'C1':45,'C2':12}
print(min(dic))

dic = {'C1':45,'C2':12}
print(min(dic.values()))

# %%
#Ejercicios

#1.
lista_numeros = [44542247/2, 21310/5, 2134747*33, 44556475, 121676, 6654067, 353254, 123134, 55**12, 611**5]

valor_maximo = max(lista_numeros) 
print(valor_maximo)

#2.
lista_numeros = [44542247, 21310, 2134747, 44556475, 121676, 6654067, 353254, 123134, 552512, 611665]
max = max(lista_numeros)
min = min(lista_numeros)

rango = max - min
print(rango)

#3.
diccionario_edades = {"Carlos":55, "María":42, "Mabel":78, "José":44, "Lucas":24, "Rocío":35, "Sebastián":19, "Catalina":2,"Darío":49}

edad_minima = min(diccionario_edades.values())
ultimo_nombre = max(diccionario_edades)

# %%
#Random

#Randint = random integer

#from "liberia" import "metodos" 

#randint() #uniform() #random() #choice() #shuffle()

from random import randint

aleatorio = randint(1,50)
print(aleatorio)

from random import *

aleatorio = round(uniform(1,5),2) #con decimal random
print(aleatorio)

aleatorio = random() #te da fracciones de entre 0 a 1 con decimales
print(aleatorio)

colores = ['azul','rojo','verde','amarillo']
aleatorio = choice(colores) # esto es para strings
print(aleatorio)

numeros = list(range(5,50,5))
shuffle(numeros) # modifica la lista, no se utiliza en strings
print(numeros)

# %%
#Ejercicios

#1.
from random import *
aleatorio = randint(1,10)
print(aleatorio)
#2.
from random import random
aleatorio = random()
print(aleatorio)
#3.
nombres = ["Carlos", "Julia", "Nicole", "Laura", "Mailen"]
from random import choice
sorteo = choice(nombres)
print(sorteo)
# Out:
# 8
# 0.6657991862582832
# Carlos

# %%
#Compresion de listas

palabra = 'python'

lista = []

for letra in palabra:
    lista.append(letra)

print(lista)


lista = [letra for letra in palabra] #forma de hacerlo mas corto
print(lista)

lista = [ff for ff in 'carlos'] #lista = var para var en lista
print(lista)


lista = [n for n in range(0,21,2)] #lista = var para var en lista
print(lista)

lista = [n * 2 for n in range(0,21,2)] #lista = var para var en lista
print(lista)

lista = [n for n in range(0,21,2) if n * 2 > 10] #lista = var para var en lista
print(lista)


lista = [n if n * 2 > 10 else 'no' for n in range(0,21,2)] #lista = var para var en lista
print(lista)


pies = [10,20,30,40,50]
metros = [p / 3.281 for p in pies]
print(metros)

# %%
#Ejercicios

#1.
valores = [1, 2, 3, 4, 5, 6, 9.5]
valores_cuadrado = [n ** 2 for n in valores]
print(valores_cuadrado)

#2.
valores = [1, 2, 3, 4, 5, 6, 9.5]
valores_pares = [n for n in valores if n %2==0]
print(valores_pares)

#3.
temperatura_fahrenheit = [32, 212, 275]
grados_celsius = [(g - 32) * (5/9) for g in temperatura_fahrenheit]
print(grados_celsius)

# %%
#Match
serie = "N-02"

match serie:
    case "N-01":
        print("Samsung")
    case "N-02":
        print("Nokia")
    case "N-03":
        print("Motorola")
    case _:
        print("no existe")

    
cliente = {'nombre':'federico',
           'edad':45,
           'ocupacion':'instructor'}
pelicula = {'titulo':'Matrix',
            'ficha_tecnica':{'protagonista':'Keanu Reeves',
                             'director': 'Lana y Lilly Wachowski'}}

elementos = [cliente, pelicula, 'libro']

for e in elementos:
    match e:
        case {'nombre': nombre,
              'edad': edad,
              'ocupacion': ocupacion}:
            print("Es un cliente")
            print(nombre,edad,ocupacion)
        case {'titulo': titulo,
              'ficha_tecnica':{'protagonista':protagonista,
                               'director':director}}:
            print("Es una pelicula")
            print(titulo,protagonista,director)
        case _:
            print("No se que es esto")
# Out:
# Nokia
# Es un cliente
# federico 45 instructor
# Es una pelicula
# Matrix Keanu Reeves Lana y Lilly Wachowski
# No se que es esto

# %%
#Proyecto 4

#Un juego funcional

#Input con solo 8 intentos, un juego con un random de numero
# a. "numero no permitido"
# b. "numero menor"
# c. "numero mayor"
# d. "Acertaste en tantos intentos"
# e. "y si no "

from random import *

numerorandom = randint(1,10)
intentos = 8
nombre = input("Dime tu nombre: ")
print(f"Bienvenido/a al juego {nombre}, tienes que adivinar el numero del 1 al 10 estoy pensando....\nTienes 8 intentos")
print("\n")
elegirnumero = int(input(f"Elige un numero por favor, tienes {intentos} intentos"))
print(numerorandom)
while elegirnumero:

        if numerorandom == elegirnumero:
             
             print(f"Has acertado, el numero que habia pensado era {numerorandom}")
             break
             int(input(f"Elige un numero por favor, tienes {intentos} intentos"))
             print("\n")

        if elegirnumero > 10:
             intentos = intentos - 1
             print(f"Es del 1 al 10. {elegirnumero} no esta permitido. Sigue intentando, te quedan {intentos} intentos")
             elegirnumero = int(input(f"Elige un numero por favor, tienes {intentos} intentos"))
             print("\n")

        if elegirnumero < -1:
             intentos = intentos - 1
             print(f"Es del 1 al 10. {elegirnumero} no esta permitido. Sigue intentando, te quedan {intentos} intentos")
             elegirnumero = int(input(f"Elige un numero por favor, tienes {intentos} intentos"))
             print("\n")

        if numerorandom > elegirnumero:
            intentos = intentos - 1
            print(f"{elegirnumero} es menor que el numero secreto. Sigue intentando, te quedan {intentos} intentos")
            elegirnumero = int(input(f"Elige un numero por favor, tienes {intentos} intentos"))
            print("\n")

        if numerorandom < elegirnumero and elegirnumero <= 10:
            intentos = intentos - 1
            print(f"WRONG!! {elegirnumero} es mayor que el numero secreto. Sigue intentando, te quedan {intentos} intentos")
            elegirnumero = int(input(f"Elige un numero por favor, tienes {intentos} intentos"))
            print("\n")

        if intentos == 1:
            print(f"Te quedaste sin intentos, el numero secreto es {numerorandom}")
            break
# Out:
# Bienvenido/a al juego Lucho, tienes que adivinar el numero del 1 al 10 estoy pensando....
# Tienes 8 intentos
#
#
# 7
# 2 es menor que el numero secreto. Sigue intentando, te quedan 7 intentos
#
#
# Has acertado, el numero que habia pensado era 7, has adivinado en 7 intentos

# %%
#Otra forma de hacer el juego

from random import randint

intentos = 0
estimado = 0
numero_secreto = randint(1,100)
nombre = input("Dime tu nombre: ")

print(f"Bueno {nombre}, he pensado un número entre 1 y 100\nTienes 8 intentos para adivinar")

while intentos < 8:
    estimado = int(input("Cuál es el número?: "))
    intentos += 1

    if estimado < numero_secreto:
        print("Mi numero es mas alto")
    elif estimado > numero_secreto:
        print("Mi numero es mas bajo")
    else:
        print(f"Felicitaciones {nombre}! Has adivinado en {intentos} intentos")
        break

if estimado != numero_secreto:
    print(f"Lo siento, se han agotado los intentos. El numero secreto era {numero_secreto}")
