# %%
#Operadores de comparacion <,>,=,==,=!,>=,<=

mi_bool = 10==25 #Es igual a 25?
print(mi_bool)

mi_bool = 5+5==18-8 #Son iguales?
print(mi_bool)

mi_bool = 'blanco'=='Blanco'.lower()
print(mi_bool)

mi_bool = '100'==100
print(mi_bool)

mi_bool = 100.0==100
print(mi_bool)

mi_bool = 100 != 100
print(mi_bool)

mi_bool = 100 != 99
print(mi_bool)

mi_bool = 100 < 300
print(mi_bool)

mi_bool = 100 > 300
print(mi_bool)


#Ejercicios
#1.
num1 = 36
num2 = 17
mi_bool = num1>=num2
print(mi_bool)

#2.
num1 = 25**0.50
num2 = 5
mi_bool = num1 == num2
print(mi_bool)

#3.
num1 = 64*3
num2 = 24*8
mi_bool = num1 != num2
print(mi_bool)

# %%
#Operadores logicos
#or, and o not

mi_bool = 4 < 5 < 6
print(mi_bool)

mi_bool = 4 < 5 and 5 > 6 #Para que de verdadero tienen que ser las 2 verdaderas
print(mi_bool)

mi_bool = 4 < 5 or 5 > 6 #Alguna de las 2 se cumple
print(mi_bool)

mi_bool = (55 == 55) and ('perro' == 'perro')
print(mi_bool)

mi_bool = 10 == 10 or 3 == 3 
print(mi_bool)

mi_bool = 10 == 1 or 3 == 3 # si se cumple alguna va a dar true
print(mi_bool)



texto = "esta frase es breve"
mi_bool = 'frase' in texto
print(mi_bool)

texto = "esta frase es breve"
mi_bool = ('frase' in texto) and ('breve' in texto)
print(mi_bool)


mi_bool = not ('a' == 'a') #
print(mi_bool)

mi_bool = not ('a' != 'a') # a no es diferente a a
print(mi_bool)


#Ejercicios
#1.
num1 = 36
num2 = 72/2
num3 = 48

mi_bool = num1 > num2 < num3
print(mi_bool)

#2.
num1 = 36
num2 = 72/2
num3 = 48

mi_bool = num1 > num2 or num2 < num3
print(mi_bool)

#3.
frase = "Cuando algo es lo suficientemente importante, lo haces incluso si las probabilidades de que salga bien no te acompañan"
palabra1 = "éxito"
palabra2 = "tecnología"

mi_bool = not palabra1 in frase and not palabra2 in frase
print(mi_bool)

# %%
#Control de flujo
#IF, ELIF, ELSE
#Sintaxis = if una_condicion:
#               print(codigo_a)
#           elif:
#               print(codigo_c)
#           elif:
#               print(codigo_d)
#           else:
#               print(codigo_b)


if 10 > 9:
    print("Es correcto")

if True:
        print("Es correcto")

x= True
if x:
      print("es correcto")

if 5 == 2:
    print("Es correcto")
else:
      print("no es correcto")


mascota = "perro"

if mascota == 'gato':
      print("Tienes un gato")
elif mascota == 'perro':
      print("Tienes un perro")
elif mascota == 'pez':
      print("Tienes un pez")
else:
      print("no se que animal tienes")




edad = 16
calificacion = 9

if edad < 18:
    print("Eres menor de edad")
    if calificacion >= 7:
        print('aprobado')
    else:
      print("Reprobado")
else:
      print("Eres adulto")



#Ejercicio

#1.
num1 = int(input("Ingresa un número:"))
num2 = int(input("Ingresa otro número:"))

if num1 > num2:
    print(f"{num1} es mayor que {num2}")
elif num2 > num1:
    print(f"{num2} es mayor que {num1}")
elif num1 == num2:
    print(f"{num1} y {num2} son iguales")
else:
    print("Jej")


#2.
edad = 16
tiene_licencia = False

if edad >= 18:
    print("Puedes conducir")
elif edad < 18:
    print("No puedes conducir aún. Debes tener 18 años y contar con una licencia")
elif tiene_licencia is False:
    print("No puedes conducir. Necesitas contar con una licencia")
else:
    print("Tienes licencia. Puedes conducir")
    

#3.
habla_ingles = True
sabe_python = False

if habla_ingles is True and sabe_python is True:
    print("Cumples con los requisitos para postularte")
elif habla_ingles is False and sabe_python is True:
    print("Para postularte, necesitas saber programar en Python y tener conocimientos de inglés")
elif habla_ingles is False and sabe_python  is True:
    print("Para postularte, necesitas tener conocimientos de inglés")
else:
    print("Para postularte, necesitas saber programar en Python")

# %%
#Loops
#Se diferencian en las definidas y las indefinidas

#Loop For

lista = ['a','b','c']

for letra in lista:
    print(letra)

lista = ['a','b','c','d']

for letra in lista:
    numero_letra = lista.index(letra) + 1
    print(f"Letra {numero_letra}: {letra}")


lista = ['pablo', 'laura', 'fede','luis','julia']

for nombre in lista:
    if nombre.startswith('l'):
        print(nombre)
    else:
        print(f"{nombre} que no comienza con 'l'")


numeros = [1,2,3,4,5]
mi_valor = 0

for numero in numeros:
    mi_valor = mi_valor + numero #mi valor vale 0, pero al hacer q esa variable sea igual a "LA VARIABLE + NUMERO
    #que numero en numeros es el que recorre la lista
print(mi_valor)

palabra = 'python'

for letra in palabra:
    print(letra)


for letra in "python":
    print(letra)




for a,b in [[1,2], [3,4],[5,6]]:
    print(a)
    print(b)


dic = {'clave':'a', 'clave':'b', 'clave3':'c'}

for item in dic.items():
    print(item)

for item in dic.values():
    print(item)

for a,b in dic.items():
    print(a,b)

# %%
#Ejercicios

#1.
alumnos_clase = ["María", "José", "Carlos", "Martina", "Isabel", "Tomás", "Daniela"]

for nombre in alumnos_clase:
    print(f"Hola {nombre}")

#2.
lista_numeros = [1,5,8,7,6,8,2,5,2,6,4,8,5,9,8,3,5,4,2,5,6,4]
suma_numeros = 0
for numero in lista_numeros:
    suma_numeros = suma_numeros + numero
print(suma_numeros)

#3.
lista_numeros = [1,5,8,7,6,8,2,5,2,6,4,8,5,9,8,3,5,4,2,5,6,4]
suma_pares = 0
suma_impares = 0
for numero in lista_numeros:
    if numero %2==0:
        suma_pares += numero
    else:
        suma_impares += numero
print("Suma de numeros pares", suma_pares)
print("Suma de numeros impares", suma_impares)

# %%
#Loop While

#Se repiten mientras se cumple una condicion.

#while una_condicion:
    #este_codigo
#else
    #otro_codigo

monedas = 5

while monedas > 0:
    print(f"tengo {monedas} monedas")
    monedas -= 1
else:
    print(f"no tengo mas monedas")



respuesta = 's'
while respuesta == 's':
    respuesta = input("¿Quieres seguir? (s/n)")
else:
    print("Gracias")

# %%
nombre = input("Tu nombre: ")
for letra in nombre:
    if letra == 'r':
        break
    print(letra)



nombre = input("Tu nombre: ")
for letra in nombre:
    if letra == 'r':
        continue
    print(letra)

# %%
#ejercicios

#1.
numero = 10
while numero > -1:
    print(numero)
    numero -= 1
#2.
numero = 50
while numero >= 0:
    if numero % 5 == 0:
        print(numero)
    numero -= 1

#3.

lista_numeros = [4, 5, 8, 7, 6, 9, 8, 2, 4, 5, 7, 1, 9, 5, 6, -1, -5, 6, -6, -4, -3]

for numero in lista_numeros:
    if numero < 0:
        break  # Interrumpe el loop si el número es negativo
    print(numero)
